# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'term', 'anarchism', 'originated', 'of', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.746193
# Nearest to time: cam, minute, oils, seldom, significant, earls, unrestricted, glutinous,
# Nearest to the: mysore, adopted, dresser, deng, decomposers, differentiability, occurrence, drab,
# Nearest to many: fawcett, collectors, bestow, cleese, nubian, kuro, rabindranath, splice,
# Nearest to three: mg, wormholes, underdogs, badly, inhale, awe, mustard, oxycoccus,
# Nearest to or: hural, nashwaak, avar, bulgaria, alleges, damasus, chron, soga,
# Nearest to a: argent, sondheim, adopting, operate, contraband, nederlandse, descendent, kava,
# Nearest to th: affiliate, ceased, clay, monopolized, random, refugees, sympathizer, neighbor,
# Nearest to american: tubules, laing, solicitation, document, railways, saronic, honest, jaina,
# Nearest to who: warmly, matic, russcol, puckett, hatti, bawdy, venizelos, topsoil,
# Nearest to on: nylon, nonfiction, arden, wadsworth, falsetto, commonsense, j, perkin,
# Nearest to years: swamp, domo, oppression, blocking, janitor, inbound, alpha, elephant,
# Nearest to if: verizon, vampires, realists, foil, hallertau, ncia, greta, militare,
# Nearest to for: wt, carrie, conscript, heroically, eleven, dystopia, ichij, transplant,
# Nearest to were: coaching, bahia, loosely, kamala, witness, unbounded, properly, lackey,
# Nearest to he: conformational, schubert, nematic, ende, karelian, persepolis, izz, plano,
# Nearest to such: yielding, bits, hesychastic, prays, nazarene, cuisines, brady, emet,
# Average loss at step 2000: 4.367548
# Average loss at step 4000: 3.868207
# Average loss at step 6000: 3.786420
# Average loss at step 8000: 3.688862
# Average loss at step 10000: 3.618150
# Nearest to time: housing, minute, unrestricted, cam, virtually, glutinous, significant, unshielded,
# Nearest to the: its, their, a, his, this, ketone, an, beaux,
# Nearest to many: remedial, these, some, cytoskeleton, collectors, cleese, rendition, fawcett,
# Nearest to three: five, four, six, two, seven, eight, nine, zero,
# Nearest to or: and, nathalie, gunto, nepalese, hpv, than, cole, nanometers,
# Nearest to a: the, infamy, kirlian, this, his, benz, quarreled, closed,
# Nearest to th: affiliate, ceased, clay, tunisia, eight, cricket, injury, refugees,
# Nearest to american: tubules, decimus, litchfield, saronic, laing, document, railways, lamb,
# Nearest to who: and, he, valentinians, yuen, matic, russcol, also, clinicians,
# Nearest to on: in, from, timescales, last, obscuring, nylon, automation, hariri,
# Nearest to years: elephant, dung, swamp, airborne, hotter, oppression, domo, alpha,
# Nearest to if: ncia, vampires, greta, realists, foil, doohan, liang, can,
# Nearest to for: gunto, with, dystopia, at, in, hinduism, of, bentsen,
# Nearest to were: are, was, had, eschenbach, have, specifically, suffers, atherton,
# Nearest to he: it, they, she, who, and, deceptively, belisarius, kluwer,
# Nearest to such: yielding, jerome, nazarene, heisenberg, well, conger, destroyers, bits,
# Average loss at step 12000: 3.608387
# Average loss at step 14000: 3.573400
# Average loss at step 16000: 3.407275
# Average loss at step 18000: 3.457411
# Average loss at step 20000: 3.542450
# Nearest to time: year, housing, ussr, glutinous, period, minute, sextus, claims,
# Nearest to the: its, their, this, screw, any, a, yalta, his,
# Nearest to many: some, these, several, all, remedial, most, other, cytoskeleton,
# Nearest to three: four, six, five, seven, two, eight, zero, one,
# Nearest to or: and, than, theatrically, duels, ellipse, with, ginger, gorgias,
# Nearest to a: the, any, this, curtain, maoism, another, tong, quarreled,
# Nearest to th: affiliate, ceased, clay, tunisia, injury, nd, potomac, liquidation,
# Nearest to american: british, decimus, brahmi, french, tubules, adin, litchfield, prayers,
# Nearest to who: he, which, also, they, valentinians, clinicians, yuen, no,
# Nearest to on: in, at, upon, laysan, against, timescales, nylon, hariri,
# Nearest to years: dung, student, elephant, hotter, airborne, oppression, swamp, ignatius,
# Nearest to if: when, vampires, greta, ncia, can, foil, snowmobile, opinions,
# Nearest to for: in, of, dystopia, gunto, and, at, through, with,
# Nearest to were: are, was, had, have, eschenbach, is, be, by,
# Nearest to he: it, she, they, who, there, belisarius, scare, but,
# Nearest to such: well, these, destroyers, jerome, yielding, heisenberg, bletchley, nazarene,
# Average loss at step 22000: 3.502733
# Average loss at step 24000: 3.491534
# Average loss at step 26000: 3.482617
# Average loss at step 28000: 3.481804
# Average loss at step 30000: 3.505720
# Nearest to time: period, year, glutinous, housing, dah, minute, humour, consequence,
# Nearest to the: their, its, his, oriented, masturbate, yalta, this, pepper,
# Nearest to many: some, several, these, most, all, remedial, cytoskeleton, those,
# Nearest to three: four, five, two, six, seven, eight, nine, one,
# Nearest to or: and, than, zelda, like, eyed, but, while, gyre,
# Nearest to a: tong, the, any, workers, priam, very, quarreled, roles,
# Nearest to th: affiliate, nd, tunisia, ceased, ce, liquidation, clay, six,
# Nearest to american: british, tubules, unfold, german, french, australian, english, brahmi,
# Nearest to who: he, they, which, also, valentinians, unser, prefaces, yuen,
# Nearest to on: upon, in, within, zy, nonfiction, cancerous, through, passionately,
# Nearest to years: year, dung, days, elephant, decades, hotter, swamp, beno,
# Nearest to if: when, can, where, vampires, is, could, before, cannot,
# Nearest to for: when, eleven, gunto, colombian, dystopia, before, hinduism, accelerator,
# Nearest to were: are, was, have, had, by, is, while, neurotoxicity,
# Nearest to he: she, it, they, who, there, moron, nacl, henryk,
# Nearest to such: well, these, jerome, heisenberg, many, some, ellipsoid, bletchley,
# Average loss at step 32000: 3.502109
# Average loss at step 34000: 3.495257
# Average loss at step 36000: 3.450645
# Average loss at step 38000: 3.303554
# Average loss at step 40000: 3.432158
# Nearest to time: year, period, way, humour, consequence, dns, vehement, glutinous,
# Nearest to the: their, a, his, any, this, its, each, masturbate,
# Nearest to many: some, several, these, most, various, those, such, certain,
# Nearest to three: four, six, two, five, seven, eight, nine, one,
# Nearest to or: and, than, is, a, inductees, icosidodecahedron, satirists, donating,
# Nearest to a: the, any, another, rden, or, no, khorasan, amethyst,
# Nearest to th: affiliate, nd, tunisia, ceased, rd, ce, potomac, liquidation,
# Nearest to american: british, australian, french, german, tubules, genotype, young, rugby,
# Nearest to who: he, which, unser, also, often, tenacious, they, yuen,
# Nearest to on: upon, emoticons, under, in, at, laysan, against, within,
# Nearest to years: days, decades, year, dung, swamp, times, feet, elephant,
# Nearest to if: when, where, is, for, before, oneness, because, pastors,
# Nearest to for: if, when, eleven, colombian, in, using, hinduism, or,
# Nearest to were: are, have, was, had, neurotoxicity, these, unison, including,
# Nearest to he: she, it, they, there, who, i, dylan, marc,
# Nearest to such: well, these, known, including, jerome, many, heisenberg, some,
# Average loss at step 42000: 3.435389
# Average loss at step 44000: 3.451583
# Average loss at step 46000: 3.449755
# Average loss at step 48000: 3.351849
# Average loss at step 50000: 3.386637
# Nearest to time: year, period, way, studio, consequence, distance, before, case,
# Nearest to the: its, their, his, a, this, briand, some, ump,
# Nearest to many: some, several, these, various, those, such, other, both,
# Nearest to three: four, six, seven, eight, five, two, nine, zero,
# Nearest to or: and, than, shipment, potencies, hangul, eyed, but, kilns,
# Nearest to a: another, any, the, tong, no, infamy, quarreled, impenetrable,
# Nearest to th: ce, nd, affiliate, six, ceased, three, tunisia, rd,
# Nearest to american: british, french, australian, english, rugby, tubules, superb, african,
# Nearest to who: he, which, she, also, they, there, tenacious, thx,
# Nearest to on: upon, in, through, within, at, under, laysan, evolutionists,
# Nearest to years: days, year, decades, times, dung, people, months, swamp,
# Nearest to if: when, where, before, because, although, though, can, while,
# Nearest to for: eleven, baen, paraphrases, cheating, gunto, against, slim, through,
# Nearest to were: are, have, was, had, specifically, be, neurotoxicity, eigenstates,
# Nearest to he: she, it, they, there, who, this, moron, marc,
# Nearest to such: well, these, known, many, jerome, including, follows, kliper,
# Average loss at step 52000: 3.436479
# Average loss at step 54000: 3.429982
# Average loss at step 56000: 3.435676
# Average loss at step 58000: 3.394093
# Average loss at step 60000: 3.397947
# Nearest to time: period, year, way, consequence, purpose, case, housing, dah,
# Nearest to the: their, a, each, its, this, any, aerosol, some,
# Nearest to many: some, several, these, various, such, most, other, including,
# Nearest to three: four, five, six, eight, seven, two, nine, one,
# Nearest to or: and, than, but, per, frisch, mua, potencies, kilns,
# Nearest to a: the, any, another, every, rden, hr, diacritics, unconvinced,
# Nearest to th: six, four, ce, nd, eight, affiliate, five, seven,
# Nearest to american: british, australian, english, french, african, european, superb, german,
# Nearest to who: he, she, which, unser, that, thx, also, crm,
# Nearest to on: upon, through, under, evolutionists, emoticons, credits, in, bnetd,
# Nearest to years: days, decades, times, year, months, dung, bissau, swamp,
# Nearest to if: when, where, before, because, then, though, since, while,
# Nearest to for: of, including, koffice, slim, although, baserunners, additional, gormenghast,
# Nearest to were: are, have, was, including, had, although, specifically, vegas,
# Nearest to he: she, it, they, there, who, never, we, i,
# Nearest to such: these, many, known, well, including, jerome, follows, kliper,
# Average loss at step 62000: 3.240795
# Average loss at step 64000: 3.257417
# Average loss at step 66000: 3.404019
# Average loss at step 68000: 3.394446
# Average loss at step 70000: 3.359527
# Nearest to time: period, year, purpose, way, juggalo, substantiate, dah, thing,
# Nearest to the: its, their, a, this, another, these, any, each,
# Nearest to many: some, several, these, various, most, all, both, other,
# Nearest to three: four, six, five, two, eight, seven, nine, zero,
# Nearest to or: and, while, than, but, cardiac, hangul, px, baryon,
# Nearest to a: another, the, quarreled, any, tong, infamy, every, roles,
# Nearest to th: ce, nd, four, rd, affiliate, ceased, tunisia, st,
# Nearest to american: british, english, african, french, italian, european, international, necrosis,
# Nearest to who: he, crm, she, unser, thx, they, which, aberfoyle,
# Nearest to on: upon, through, in, within, across, under, bnetd, obscuring,
# Nearest to years: days, decades, months, year, times, dung, bissau, centuries,
# Nearest to if: when, where, though, before, while, because, can, liliales,
# Nearest to for: in, gunto, including, of, eleven, colombian, while, slim,
# Nearest to were: are, was, have, had, be, been, including, specifically,
# Nearest to he: she, it, they, who, there, surpass, never, we,
# Nearest to such: these, well, known, including, many, follows, jerome, kliper,
# Average loss at step 72000: 3.372889
# Average loss at step 74000: 3.349317
# Average loss at step 76000: 3.312592
# Average loss at step 78000: 3.353895
# Average loss at step 80000: 3.379653
# Nearest to time: period, year, clarify, guardianship, thing, substantiate, minute, observables,
# Nearest to the: its, his, their, this, a, masturbate, each, situated,
# Nearest to many: some, several, various, these, both, most, all, numerous,
# Nearest to three: six, four, five, two, eight, seven, nine, one,
# Nearest to or: and, while, than, wolfram, px, potencies, headless, eyed,
# Nearest to a: another, the, investiture, every, quarreled, impenetrable, crossings, heck,
# Nearest to th: nd, ce, rd, three, six, ceased, four, five,
# Nearest to american: british, french, german, italian, irish, african, international, english,
# Nearest to who: he, which, crm, she, often, they, unser, divisibility,
# Nearest to on: upon, through, in, under, during, within, laysan, at,
# Nearest to years: days, decades, months, times, year, dung, bissau, centuries,
# Nearest to if: when, though, where, before, since, because, then, while,
# Nearest to for: theorist, stereotypically, mellow, colombian, eleven, ffff, fairness, bunk,
# Nearest to were: are, was, had, have, atherton, been, neurotoxicity, be,
# Nearest to he: she, it, they, there, who, never, henryk, redding,
# Nearest to such: well, these, known, follows, including, regarded, certain, kliper,
# Average loss at step 82000: 3.407864
# Average loss at step 84000: 3.410483
# Average loss at step 86000: 3.389464
# Average loss at step 88000: 3.355893
# Average loss at step 90000: 3.361909
# Nearest to time: period, clarify, substantiate, year, chilperic, thing, guardianship, juggalo,
# Nearest to the: its, any, their, his, this, a, kursk, each,
# Nearest to many: some, several, these, various, all, most, those, numerous,
# Nearest to three: five, four, two, eight, six, seven, nine, zero,
# Nearest to or: and, while, but, than, spiracles, including, busey, empirically,
# Nearest to a: quarreled, the, another, any, infamy, tong, every, investiture,
# Nearest to th: eight, rd, ceased, nd, ce, five, one, affiliate,
# Nearest to american: british, french, italian, english, african, german, european, australian,
# Nearest to who: he, thx, often, they, which, crm, also, but,
# Nearest to on: upon, under, in, through, laysan, at, nonfiction, within,
# Nearest to years: days, decades, months, year, times, weeks, centuries, hours,
# Nearest to if: when, where, since, though, before, because, can, while,
# Nearest to for: of, including, against, ct, spectroscopic, nas, colombian, ffff,
# Nearest to were: are, had, was, have, while, although, atherton, been,
# Nearest to he: she, it, they, there, who, henryk, but, later,
# Nearest to such: these, well, known, follows, certain, many, including, regarded,
# Average loss at step 92000: 3.397307
# Average loss at step 94000: 3.252390
# Average loss at step 96000: 3.362378
# Average loss at step 98000: 3.242326
# Average loss at step 100000: 3.354353
# Nearest to time: period, juggalo, clarify, observables, thing, year, chilperic, scioto,
# Nearest to the: their, its, his, our, your, a, some, her,
# Nearest to many: several, some, these, various, certain, few, all, numerous,
# Nearest to three: four, two, six, five, seven, eight, nine, zero,
# Nearest to or: and, than, while, sinauer, polar, cardiac, ulmanis, repeaters,
# Nearest to a: another, any, the, investiture, quarreled, pcp, incongruous, enough,
# Nearest to th: nd, rd, ceased, one, ce, affiliate, hallucinatory, brick,
# Nearest to american: british, italian, french, english, australian, christianum, canadian, german,
# Nearest to who: he, thx, she, and, that, which, crm, also,
# Nearest to on: upon, under, within, at, through, in, around, onto,
# Nearest to years: days, decades, year, months, times, weeks, centuries, hours,
# Nearest to if: when, where, though, while, because, before, since, so,
# Nearest to for: when, colombian, if, before, mayonnaise, including, although, while,
# Nearest to were: are, have, was, although, had, these, eigenstates, is,
# Nearest to he: she, it, they, who, there, we, henryk, surpass,
# Nearest to such: well, known, these, including, follows, certain, those, serve,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
